# %%
# %sql
TRUNCATE TABLE delta_bronze_dev_01.b_automl_fact_revenue_forecast;
TRUNCATE TABLE delta_silver_dev_01.s_automl_fact_revenue_forecast;
TRUNCATE TABLE delta_gold_dev_01.g_automl_fact_revenue_forecast;
TRUNCATE TABLE delta_platinum_dev_01.p_automl_fact_revenue_forecast;
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql --utilization type dimension   # null for old data.

DROP TABLE IF EXISTS delta_bronze_dev_01.b_automl_fact_revenue_forecast;
DROP TABLE IF EXISTS delta_silver_dev_01.s_automl_fact_revenue_forecast;
DROP TABLE IF EXISTS delta_gold_dev_01.g_automl_fact_revenue_forecast;
DROP TABLE IF EXISTS delta_platinum_dev_01.p_automl_fact_revenue_forecast;

CREATE TABLE delta_bronze_dev_01.b_automl_fact_revenue_forecast
(
    Forecast_Date DATE,
    Snapshot_Date DATE,
    End_of_Month DATE,
    Sub_Region_Code string,
    Relative_Month_Offset int,
    Relative_Offset int,
    Relative_Snapshot_Month_Offset int,
    Snapshot_Day_of_Month int,
    Snp_Seq_No int,
    Currency_Code string,
    Predicted_Revenue numeric(32,6),
    Revenue numeric(32,6),
    Project_Period_Count int, 
    Project_Count int ,
    Project_Period_Price numeric(32,6),
    Project_Price numeric(32,6),
    Conversions numeric(32,6),
    Opportunity_Period_Count int, 
    Opportunity_Count int, 
    Current_Opp_Period_Value numeric(32,6),
    Opportunity_Value numeric(32,6),
    Win_Rate numeric(32,6),
    Nominal_Hours numeric(32,6),
    Utilization_Billable numeric(32,6),
    Headcount_Billable numeric(32,6),
    Headcount_Non_Billable numeric(32,6),
    Headcount_Contingent_Billable numeric(32,6),
    Headcount_Contingent_Non_Billable numeric(32,6),
    Headcount_Contingent_Unknown numeric(32,6),
    EURONEXT_100 numeric(32,6),
    FTSE_100 numeric(32,6),
    Nikkei_225 numeric(32,6),
    SP_500 numeric(32,6),
    SSE_Composite_Index numeric(32,6),
    Pipeline_Trend numeric(32,6),
    Pipeline_Active_Unrecognized numeric(32,6),
    Pipeline_Opportunity numeric(32,6),
    Pipeline_Opportunity_ML numeric(32,6),
    Pipeline_Recognized numeric(32,6),
    Pipeline_at_100_Percent_Active_Unrecognized numeric(32,6),
    Pipeline_at_100_Percent_Opportunity numeric(32,6),
    Pipeline_at_100_Percent_Opportunity_ML numeric(32,6),
    Pipeline_at_100_Percent_Recognized numeric(32,6),
    Yield_Active_Unrecognized numeric(32,6),
    Yield_Opportunity_ML numeric(32,6),
    Yield_Recognized numeric(32,6),
    Run_Date DATE,
    Run_ID string,
    IBIBatchID bigint,
    IBIBatchStartDateTime timestamp,
    IBIHashCode string
)
USING DELTA
LOCATION "/mnt/dev/bronze/b_automl_fact_revenue_forecast";

CREATE TABLE delta_silver_dev_01.s_automl_fact_revenue_forecast
(
    Forecast_Date DATE,
    Snapshot_Date DATE,
    End_of_Month DATE,
    Sub_Region_Code string,
    Relative_Month_Offset int,
    Relative_Offset int,
    Relative_Snapshot_Month_Offset int,
    Snapshot_Day_of_Month int,
    Snp_Seq_No int,
    Currency_Code string,
    Predicted_Revenue numeric(32,6),
    Revenue numeric(32,6),
    Project_Period_Count int, 
    Project_Count int ,
    Project_Period_Price numeric(32,6),
    Project_Price numeric(32,6),
    Conversions numeric(32,6),
    Opportunity_Period_Count int, 
    Opportunity_Count int, 
    Current_Opp_Period_Value numeric(32,6),
    Opportunity_Value numeric(32,6),
    Win_Rate numeric(32,6),
    Nominal_Hours numeric(32,6),
    Utilization_Billable numeric(32,6),
    Headcount_Billable numeric(32,6),
    Headcount_Non_Billable numeric(32,6),
    Headcount_Contingent_Billable numeric(32,6),
    Headcount_Contingent_Non_Billable numeric(32,6),
    Headcount_Contingent_Unknown numeric(32,6),
    EURONEXT_100 numeric(32,6),
    FTSE_100 numeric(32,6),
    Nikkei_225 numeric(32,6),
    SP_500 numeric(32,6),
    SSE_Composite_Index numeric(32,6),
    Pipeline_Trend numeric(32,6),
    Pipeline_Active_Unrecognized numeric(32,6),
    Pipeline_Opportunity numeric(32,6),
    Pipeline_Opportunity_ML numeric(32,6),
    Pipeline_Recognized numeric(32,6),
    Pipeline_at_100_Percent_Active_Unrecognized numeric(32,6),
    Pipeline_at_100_Percent_Opportunity numeric(32,6),
    Pipeline_at_100_Percent_Opportunity_ML numeric(32,6),
    Pipeline_at_100_Percent_Recognized numeric(32,6),
    Yield_Active_Unrecognized numeric(32,6),
    Yield_Opportunity_ML numeric(32,6),
    Yield_Recognized numeric(32,6),
    Run_Date DATE,
    Run_ID string,
    IBIBatchID	bigint,
    IBICreatedBy	string,
    IBIUpdatedBy	string,
    IBICreatedDate	timestamp,
    IBIUpdatedDate	timestamp,
    IBIChangeReason	string,
    IBIOperationType	string,
    IBISourceFormat	string,
    IBISourceName	string,
    IBISourcePath	string,
    IBISourceSystemID	string,
    IBIDataCategory	string,
    IBILineageLevel	int,
    IBIIngestionMethod	string,
    IBIBatchStartDateTime	timestamp,
    IBIDataClassification	string,
    IBIProgramName	string,
    IBIProgramPath	string,
    IBIValidationStatus	string,
    IBIHashCode	string
)
USING DELTA
LOCATION "/mnt/dev/silver/s_automl_fact_revenue_forecast";

CREATE TABLE delta_gold_dev_01.g_automl_fact_revenue_forecast
(
    RevenueForecastKey int,
    ValidFrom DATE,
    ValidTo DATE,
    Forecast_Date DATE,
    Snapshot_Date DATE,
    End_of_Month DATE,
    Sub_Region_Code string,
    Relative_Month_Offset int,
    Relative_Offset int,
    Relative_Snapshot_Month_Offset int,
    Snapshot_Day_of_Month int,
    Snp_Seq_No int,
    Currency_Code string,
    Predicted_Revenue numeric(32,6),
    Revenue numeric(32,6),
    Project_Period_Count int, 
    Project_Count int ,
    Project_Period_Price numeric(32,6),
    Project_Price numeric(32,6),
    Conversions numeric(32,6),
    Opportunity_Period_Count int, 
    Opportunity_Count int, 
    Current_Opp_Period_Value numeric(32,6),
    Opportunity_Value numeric(32,6),
    Win_Rate numeric(32,6),
    Nominal_Hours numeric(32,6),
    Utilization_Billable numeric(32,6),
    Headcount_Billable numeric(32,6),
    Headcount_Non_Billable numeric(32,6),
    Headcount_Contingent_Billable numeric(32,6),
    Headcount_Contingent_Non_Billable numeric(32,6),
    Headcount_Contingent_Unknown numeric(32,6),
    EURONEXT_100 numeric(32,6),
    FTSE_100 numeric(32,6),
    Nikkei_225 numeric(32,6),
    SP_500 numeric(32,6),
    SSE_Composite_Index numeric(32,6),
    Pipeline_Trend numeric(32,6),
    Pipeline_Active_Unrecognized numeric(32,6),
    Pipeline_Opportunity numeric(32,6),
    Pipeline_Opportunity_ML numeric(32,6),
    Pipeline_Recognized numeric(32,6),
    Pipeline_at_100_Percent_Active_Unrecognized numeric(32,6),
    Pipeline_at_100_Percent_Opportunity numeric(32,6),
    Pipeline_at_100_Percent_Opportunity_ML numeric(32,6),
    Pipeline_at_100_Percent_Recognized numeric(32,6),
    Yield_Active_Unrecognized numeric(32,6),
    Yield_Opportunity_ML numeric(32,6),
    Yield_Recognized numeric(32,6),
    Run_Date DATE,
    Run_ID string,
    IBIBatchID	bigint,
    IBICreatedBy	string,
    IBIUpdatedBy	string,
    IBICreatedDate	timestamp,
    IBIUpdatedDate	timestamp,
    IBIChangeReason	string,
    IBIOperationType	string,
    IBISourceFormat	string,
    IBISourceName	string,
    IBISourcePath	string,
    IBISourceSystemID	string,
    IBIDataCategory	string,
    IBILineageLevel	int,
    IBIIngestionMethod	string,
    IBIBatchStartDateTime	timestamp,
    IBIDataClassification	string,
    IBIProgramName	string,
    IBIProgramPath	string,
    IBIValidationStatus	string,
    IBIHashCode	string,
    IsLatest boolean,
    IsDeleted boolean
)
USING DELTA
LOCATION "/mnt/dev/gold/g_automl_fact_revenue_forecast";

CREATE TABLE delta_platinum_dev_01.p_automl_fact_revenue_forecast
(
    RevenueForecastKey int,
    ValidFrom DATE,
    ValidTo DATE,
    ValidFromDateKey int,
    ValidToDateKey int,
    CreatedDateKey int,
    UpdatedDateKey int,
    BatchStartDateKey int,
    ForecastDateKey int,
    SnapshotDateKey int,
    EndOfMonthDateKey int,
    RunDateKey int,
    CurrencyKey int, 
    Forecast_Date DATE,
    Snapshot_Date DATE,
    End_of_Month DATE,
    Sub_Region_Code string,
    Relative_Month_Offset int,
    Relative_Offset int,
    Relative_Snapshot_Month_Offset int,
    Snapshot_Day_of_Month int,
    Snp_Seq_No int,
    Currency_Code string,
    Predicted_Revenue numeric(32,6),
    Revenue numeric(32,6),
    Project_Period_Count int, 
    Project_Count int ,
    Project_Period_Price numeric(32,6),
    Project_Price numeric(32,6),
    Conversions numeric(32,6),
    Opportunity_Period_Count int, 
    Opportunity_Count int, 
    Current_Opp_Period_Value numeric(32,6),
    Opportunity_Value numeric(32,6),
    Win_Rate numeric(32,6),
    Nominal_Hours numeric(32,6),
    Utilization_Billable numeric(32,6),
    Headcount_Billable numeric(32,6),
    Headcount_Non_Billable numeric(32,6),
    Headcount_Contingent_Billable numeric(32,6),
    Headcount_Contingent_Non_Billable numeric(32,6),
    Headcount_Contingent_Unknown numeric(32,6),
    EURONEXT_100 numeric(32,6),
    FTSE_100 numeric(32,6),
    Nikkei_225 numeric(32,6),
    SP_500 numeric(32,6),
    SSE_Composite_Index numeric(32,6),
    Pipeline_Trend numeric(32,6),
    Pipeline_Active_Unrecognized numeric(32,6),
    Pipeline_Opportunity numeric(32,6),
    Pipeline_Opportunity_ML numeric(32,6),
    Pipeline_Recognized numeric(32,6),
    Pipeline_at_100_Percent_Active_Unrecognized numeric(32,6),
    Pipeline_at_100_Percent_Opportunity numeric(32,6),
    Pipeline_at_100_Percent_Opportunity_ML numeric(32,6),
    Pipeline_at_100_Percent_Recognized numeric(32,6),
    Yield_Active_Unrecognized numeric(32,6),
    Yield_Opportunity_ML numeric(32,6),
    Yield_Recognized numeric(32,6),  
    Run_Date DATE,
    Run_ID string,
    IBIBatchID	bigint,
    IBICreatedBy	string,
    IBIUpdatedBy	string,
    IBICreatedDate	timestamp,
    IBIUpdatedDate	timestamp,
    IBIChangeReason	string,
    IBIOperationType	string,
    IBISourceFormat	string,
    IBISourceName	string,
    IBISourcePath	string,
    IBISourceSystemID	string,
    IBIDataCategory	string,
    IBILineageLevel	int,
    IBIIngestionMethod	string,
    IBIBatchStartDateTime	timestamp,
    IBIDataClassification	string,
    IBIProgramName	string,
    IBIProgramPath	string,
    IBIValidationStatus	string,
    IBIHashCode	string,
    IsLatest boolean,
    IsDeleted boolean
)
USING DELTA
LOCATION "/mnt/dev/platinum/p_automl_fact_revenue_forecast";
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql
ALTER TABLE delta_bronze_dev_01.b_automl_fact_revenue_forecast
ADD COLUMNS (Explained_Variance numeric(32,6), 
             Mean_Absolute_Error numeric(32,6),
             Mean_Absolute_Percentage_Error numeric(32,6),
             Median_Absolute_Error numeric(32,6),
             Normalized_Mean_Absolute_Error numeric(32,6),
             Normalized_Median_Absolute_Error numeric(32,6),
             Normalized_Root_Mean_Squared_Error numeric(32,6),
             Normalized_Root_Mean_Squared_Log_Error numeric(32,6),
             R2_Score numeric(32,6),
             Root_Mean_Squared_Error numeric(32,6),
             Root_Mean_Squared_Log_Error numeric(32,6),
             Spearman_Correlation numeric(32,6));
             
ALTER TABLE delta_silver_dev_01.s_automl_fact_revenue_forecast
ADD COLUMNS (Explained_Variance numeric(32,6), 
             Mean_Absolute_Error numeric(32,6),
             Mean_Absolute_Percentage_Error numeric(32,6),
             Median_Absolute_Error numeric(32,6),
             Normalized_Mean_Absolute_Error numeric(32,6),
             Normalized_Median_Absolute_Error numeric(32,6),
             Normalized_Root_Mean_Squared_Error numeric(32,6),
             Normalized_Root_Mean_Squared_Log_Error numeric(32,6),
             R2_Score numeric(32,6),
             Root_Mean_Squared_Error numeric(32,6),
             Root_Mean_Squared_Log_Error numeric(32,6),
             Spearman_Correlation numeric(32,6));
             
ALTER TABLE delta_gold_dev_01.g_automl_fact_revenue_forecast
ADD COLUMNS (Explained_Variance numeric(32,6), 
             Mean_Absolute_Error numeric(32,6),
             Mean_Absolute_Percentage_Error numeric(32,6),
             Median_Absolute_Error numeric(32,6),
             Normalized_Mean_Absolute_Error numeric(32,6),
             Normalized_Median_Absolute_Error numeric(32,6),
             Normalized_Root_Mean_Squared_Error numeric(32,6),
             Normalized_Root_Mean_Squared_Log_Error numeric(32,6),
             R2_Score numeric(32,6),
             Root_Mean_Squared_Error numeric(32,6),
             Root_Mean_Squared_Log_Error numeric(32,6),
             Spearman_Correlation numeric(32,6));
             
ALTER TABLE delta_platinum_dev_01.p_automl_fact_revenue_forecast
ADD COLUMNS (Explained_Variance numeric(32,6), 
             Mean_Absolute_Error numeric(32,6),
             Mean_Absolute_Percentage_Error numeric(32,6),
             Median_Absolute_Error numeric(32,6),
             Normalized_Mean_Absolute_Error numeric(32,6),
             Normalized_Median_Absolute_Error numeric(32,6),
             Normalized_Root_Mean_Squared_Error numeric(32,6),
             Normalized_Root_Mean_Squared_Log_Error numeric(32,6),
             R2_Score numeric(32,6),
             Root_Mean_Squared_Error numeric(32,6),
             Root_Mean_Squared_Log_Error numeric(32,6),
             Spearman_Correlation numeric(32,6));
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %sql
ALTER TABLE delta_bronze_dev_01.b_automl_fact_revenue_forecast
ADD COLUMNS (Current_Opp_Period_Count int, 
             Opportunity_Period_Value numeric(32,6));
             
ALTER TABLE delta_silver_dev_01.s_automl_fact_revenue_forecast
ADD COLUMNS (Current_Opp_Period_Count int, 
             Opportunity_Period_Value numeric(32,6));
             
ALTER TABLE delta_gold_dev_01.g_automl_fact_revenue_forecast
ADD COLUMNS (Current_Opp_Period_Count int, 
             Opportunity_Period_Value numeric(32,6));
             
ALTER TABLE delta_platinum_dev_01.p_automl_fact_revenue_forecast
ADD COLUMNS (Current_Opp_Period_Count int, 
             Opportunity_Period_Value numeric(32,6));
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
from delta.tables import *
table_name = "delta_bronze_dev_01.b_automl_fact_revenue_forecast"
spark.read.table(table_name)\
  .withColumnRenamed("Relative_Offset", "Relative_EOM_Snp_Month_Offset")\
  .write\
  .format("delta")\
  .mode("overwrite")\
  .option("overwriteSchema", "true")\
  .saveAsTable(table_name)

table_name = "delta_silver_dev_01.s_automl_fact_revenue_forecast"
spark.read.table(table_name)\
  .withColumnRenamed("Relative_Offset", "Relative_EOM_Snp_Month_Offset")\
  .write\
  .format("delta")\
  .mode("overwrite")\
  .option("overwriteSchema", "true")\
  .saveAsTable(table_name)

table_name = "delta_gold_dev_01.g_automl_fact_revenue_forecast"
spark.read.table(table_name)\
  .withColumnRenamed("Relative_Offset", "Relative_EOM_Snp_Month_Offset")\
  .write\
  .format("delta")\
  .mode("overwrite")\
  .option("overwriteSchema", "true")\
  .saveAsTable(table_name)

table_name = "delta_platinum_dev_01.p_automl_fact_revenue_forecast"
spark.read.table(table_name)\
  .withColumnRenamed("Relative_Offset", "Relative_EOM_Snp_Month_Offset")\
  .write\
  .format("delta")\
  .mode("overwrite")\
  .option("overwriteSchema", "true")\
  .saveAsTable(table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
