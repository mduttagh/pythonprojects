# %%
# %sql
select distinct 1,forecast_date from delta_silver_prod_01.s_automl_fact_revenue_forecast
union all 
select distinct 2,forecast_date  from delta_gold_prod_01.g_automl_fact_revenue_forecast 
union all 
select distinct 3,forecast_date from delta_platinum_prod_01.p_automl_fact_revenue_forecast 
order by 1,2

-- select distinct 1,  forecast_date from delta_silver_prod_01.s_automl_fact_revenue_forecast where forecast_date like '2021-04%' or forecast_date in ('2021-09-20','2021-09-26')
-- union all 
-- select distinct 2,  forecast_date  from delta_gold_prod_01.g_automl_fact_revenue_forecast where forecast_date like '2021-04%' or forecast_date in ('2021-09-20','2021-09-26')
-- union all 
-- select distinct 3,  forecast_date from delta_platinum_prod_01.p_automl_fact_revenue_forecast where forecast_date like '2021-04%' or forecast_date in ('2021-09-20','2021-09-26')
-- order by 1,2

-- delete from delta_silver_prod_01.s_automl_fact_revenue_forecast where forecast_date like '2021-04%' or forecast_date in ('2021-09-20','2021-09-26');
-- delete from delta_gold_prod_01.g_automl_fact_revenue_forecast where forecast_date like '2021-04%' or forecast_date in ('2021-09-20','2021-09-26');
-- delete from delta_platinum_prod_01.p_automl_fact_revenue_forecast where forecast_date like '2021-04%' or forecast_date in ('2021-09-20','2021-09-26');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- select distinct 1,  count(forecast_date) from delta_silver_prod_01.s_automl_fact_revenue_forecast
-- union all 
-- select distinct 2,  count(forecast_date)  from delta_gold_prod_01.g_automl_fact_revenue_forecast 
-- union all 
-- select distinct 3,  count(forecast_date) from delta_platinum_prod_01.p_automl_fact_revenue_forecast 
-- order by 1,2

-- select distinct 1,  count(forecast_date) from delta_silver_prod_01.s_automl_fact_revenue_forecast where forecast_date  in ('2021-09-02','2021-09-28')
-- union all 
-- select distinct 2,  count(forecast_date)  from delta_gold_prod_01.g_automl_fact_revenue_forecast where forecast_date in ('2021-09-02','2021-09-28')
-- union all 
-- select distinct 3,  count(forecast_date) from delta_platinum_prod_01.p_automl_fact_revenue_forecast where forecast_date in ('2021-09-02','2021-09-28')
-- order by 1,2

-- delete from delta_silver_prod_01.s_automl_fact_revenue_forecast where forecast_date  in ('2021-09-02','2021-09-28');
-- delete from delta_gold_prod_01.g_automl_fact_revenue_forecast where forecast_date  in ('2021-09-02','2021-09-28');
-- delete from delta_platinum_prod_01.p_automl_fact_revenue_forecast where forecast_date  in ('2021-09-02','2021-09-28');

-- select distinct forecast_date from delta_platinum_prod_01.p_automl_fact_revenue_forecast
-- order by 1 desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select distinct 1, count(forecast_date) from delta_silver_prod_01.s_automl_fact_revenue_forecast
union all 
select distinct 2, count(forecast_date)  from delta_gold_prod_01.g_automl_fact_revenue_forecast 
union all 
select distinct 3, count(forecast_date) from delta_platinum_prod_01.p_automl_fact_revenue_forecast 
order by 1,2

-- select distinct 1,  count(forecast_date) from delta_silver_prod_01.s_automl_fact_revenue_forecast where forecast_date in ('2021-12-10','2021-12-09','2021-11-03')
-- union all 
-- select distinct 2,  count(forecast_date)  from delta_gold_prod_01.g_automl_fact_revenue_forecast where forecast_date in ('2021-12-10','2021-12-09','2021-11-03')
-- union all 
-- select distinct 3,  count(forecast_date) from delta_platinum_prod_01.p_automl_fact_revenue_forecast where forecast_date in ('2021-12-10','2021-12-09','2021-11-03')
-- order by 1,2

-- delete from delta_silver_prod_01.s_automl_fact_revenue_forecast where forecast_date  in ('2021-12-10','2021-12-09','2021-11-03');
-- delete from delta_gold_prod_01.g_automl_fact_revenue_forecast where forecast_date  in ('2021-12-10','2021-12-09','2021-11-03');
-- delete from delta_platinum_prod_01.p_automl_fact_revenue_forecast where forecast_date  in ('2021-12-10','2021-12-09','2021-11-03');

--select * from  delta_platinum_prod_01.p_automl_fact_revenue_forecast
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>1</th><th>count(forecast_date)</th></tr></thead><tbody><tr><td>1</td><td>112080</td></tr><tr><td>2</td><td>112080</td></tr><tr><td>3</td><td>112080</td></tr></tbody></table></div>
