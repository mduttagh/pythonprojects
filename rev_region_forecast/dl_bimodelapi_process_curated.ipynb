# %%
#define widgets -- NEEDS TO DEFINE IT ONCE
#dbutils.widgets.text("environment", "","")
#dbutils.widgets.text("system_name", "","")

#dynamic variables (pass it from ADF)
environment = dbutils.widgets.get("environment")
system_name = dbutils.widgets.get("system_name")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %run ../../bi_config/pbi_common
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import os

notebook = os.path.basename(getNotebookPath())

try:
  #process_curated(environment,system_name)        # Generate all files for given system name
  #process_curated("dev","d365")                  # Generate all files for given system name
  process_curated(environment,system_name,"p_automl_fact_revenue_forecast")  # Generate a file for given system name and table
  
except Exception as error: 
  print(error)
  log_error("{} {}".format(notebook, error)) #log error in sentry
  #raise dbutils.notebook.exit(error) #raise the exception
  raise error #raise the exception
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">df_bi_config_curated_tables DataFrame[ConfigID: int, EnvironmentName: string, SystemName: string, TargetFilePath: string, TargetFileName: string, TargetFieldName: string, SourceTableName: string, SourceFieldName: string, IBICreatedBy: string, IBIUpdatedBy: string, IBICreatedDate: timestamp, IBIUpdatedDate: timestamp]
# platinum_folder_path /mnt/prod/platinum
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ConfigID</th><th>EnvironmentName</th><th>SystemName</th><th>TargetFilePath</th><th>TargetFileName</th><th>TargetFieldName</th><th>SourceTableName</th><th>SourceFieldName</th><th>IBICreatedBy</th><th>IBIUpdatedBy</th><th>IBICreatedDate</th><th>IBIUpdatedDate</th></tr></thead><tbody><tr><td>18867</td><td>prod</td><td>bimodelapi</td><td>/curated/bimodelapi/</td><td>Revenue Forecast.csv</td><td>BatchStartDateKey</td><td>p_automl_fact_revenue_forecast</td><td>BatchStartDateKey</td><td>bi@ideo.com</td><td>bi@ideo.com</td><td>2021-06-16T04:27:10.743+0000</td><td>2021-06-16T04:27:10.743+0000</td></tr><tr><td>18868</td><td>prod</td><td>bimodelapi</td><td>/curated/bimodelapi/</td><td>Revenue Forecast.csv</td><td>Conversions_</td><td>p_automl_fact_revenue_forecast</td><td>Conversions</td><td>bi@ideo.com</td><td>bi@ideo.com</td><td>2021-06-16T04:27:10.743+0000</td><td>2021-06-16T04:27:10.743+0000</td></tr><tr><td>18869</td><td>prod</td><td>bimodelapi</td><td>/curated/bimodelapi/</td><td>Revenue Forecast.csv</td><td>CreatedDateKey</td><td>p_automl_fact_revenue_forecast</td><td>CreatedDateKey</td><td>bi@ideo.com</td><td>bi@ideo.com</td><td>2021-06-16T04:27:10.743+0000</td><td>2021-06-16T04:27:10.743+0000</td></tr><tr><td>18870</td><td>prod</td><td>bimodelapi</td><td>/curated/bimodelapi/</td><td>Revenue Forecast.csv</td><td>CurrencyKey</td><td>p_automl_fact_revenue_forecast</td><td>CurrencyKey</td><td>bi@ideo.com</td><td>bi@ideo.com</td><td>2021-06-16T04:27:10.743+0000</td><td>2021-06-16T04:27:10.743+0000</td></tr><tr><td>18871</td><td>prod</td><td>bimodelapi</td><td>/curated/bimodelapi/</td><td>Revenue Forecast.csv</td><td>Currency Code</td><td>p_automl_fact_revenue_forecast</td><td>Currency_Code</td><td>bi@ideo.com</td><td>bi@ideo.com</td><td>2021-06-16T04:27:10.743+0000</td><td>2021-06-16T04:27:10.743+0000</td></tr><tr><td>18872</td><td>prod</td><td>bimodelapi</td><td>/curated/bimodelapi/</td><td>Revenue Forecast.csv</td><td>Current Opp Period Count_</td><td>p_automl_fact_revenue_forecast</td><td>Current_Opp_Period_Count</td><td>bi@ideo.com</td><td>bi@ideo.com</td><td>2021-06-16T04:27:10.743+0000</td><td>2021-06-16T04:27:10.743+0000</td></tr><tr><td>18873</td><td>prod</td><td>bimodelapi</td><td>/curated/bimodelapi/</td><td>Revenue Forecast.csv</td><td>Current Opp Period Value_</td><td>p_automl_fact_revenue_forecast</td><td>Current_Opp_Period_Value</td><td>bi@ideo.com</td><td>bi@ideo.com</td><td>2021-06-16T04:27:10.743+0000</td><td>2021-06-16T04:27:10.743+0000</td></tr><tr><td>18874</td><td>prod</td><td>bimodelapi</td><td>/curated/bimodelapi/</td><td>Revenue Forecast.csv</td><td>EURONEXT 100_</td><td>p_automl_fact_revenue_forecast</td><td>EURONEXT_100</td><td>bi@ideo.com</td><td>bi@ideo.com</td><td>2021-06-16T04:27:10.743+0000</td><td>2021-06-16T04:27:10.743+0000</td></tr><tr><td>18875</td><td>prod</td><td>bimodelapi</td><td>/curated/bimodelapi/</td><td>Revenue Forecast.csv</td><td>EndOfMonthDateKey</td><td>p_automl_fact_revenue_forecast</td><td>EndOfMonthDateKey</td><td>bi@ideo.com</td><td>bi@ideo.com</td><td>2021-06-16T04:27:10.743+0000</td><td>2021-06-16T04:27:10.743+0000</td></tr><tr><td>18876</td><td>prod</td><td>bimodelapi</td><td>/curated/bimodelapi/</td><td>Revenue Forecast.csv</td><td>End of Month</td><td>p_automl_fact_revenue_forecast</td><td>End_of_Month</td><td>bi@ideo.com</td><td>bi@ideo.com</td><td>2021-06-16T04:27:10.743+0000</td><td>2021-06-16T04:27:10.743+0000</td></tr><tr><td>18877</td><td>prod</td><td>bimodelapi</td><td>/curated/bimodelapi/</td><td>Revenue Forecast.csv</td><td>Explained Variance_</td><td>p_automl_fact_revenue_forecast</td><td>Explained_Variance</td><td>bi@ideo.com</td><td>bi@ideo.com</td><td>2021-06-16T04:27:10.743+0000</td><td>2021-06-16T04:27:10.743+0000</td></tr><tr><td>18878</td><td>prod</td><td>bimodelapi</td><td>/curated/bimodelapi/</td><td>Revenue Forecast.csv</td><td>FTSE 100_</t ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Revenue Forecast]
# </div>
